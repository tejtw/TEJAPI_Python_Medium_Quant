# %%
import tejapi
tejapi.ApiConfig.api_base="http://10.10.10.66"
tejapi.ApiConfig.api_key ="rCQ1mgb1y8bIgShFl5lLinrXWhjwvD"

# %%
data = tejapi.get('TWN/AMTOP1',coid='2330',mdate='2017-01-10')

# %%
data
# Out:
#       coid                     mdate            key3  \
# None
# 0     2330 2017-01-10 00:00:00+00:00     000102 合庫證券
# 1     2330 2017-01-10 00:00:00+00:00     000104 臺銀證券
# 2     2330 2017-01-10 00:00:00+00:00     000116 日盛證券
# 3     2330 2017-01-10 00:00:00+00:00    000136 麥格理資本
# 4     2330 2017-01-10 00:00:00+00:00   000138 台灣匯立證券
# 5     2330 2017-01-10 00:00:00+00:00     000144 美林證券
# 6     2330 2017-01-10 00:00:00+00:00   000147 台灣摩根士丹
# 7     2330 2017-01-10 00:00:00+00:00     000148 美商高盛
# 8     2330 2017-01-10 00:00:00+00:00     000152 瑞士信貸
# 9     2330 2017-01-10 00:00:00+00:00    000153 德意志證券
# 10    2330 2017-01-10 00:00:00+00:00     000156 港商野村
# 11    2330 2017-01-10 00:00:00+00:00     000159 花旗環球
# 12    2330 2017-01-10 00:00:00+00:00  000165 瑞銀證券(新)
# 13    2330 2017-01-10 00:00:00+00:00     000538 第一金證
# 14    2330 2017-01-10 00:00:00+00:00     000601 奔亞證券
# 15    2330 2017-01-10 00:00:00+00:00     000700 兆豐證券
# 16    2330 2017-01-10 00:00:00+00:00     000779 國票證券
# ...

# %%
mitosheet.sheet(data,AAA)
# Out:
# MitoWidget(analysis_name='UUID-25511bd5-1b05-498d-8c93-2136d5a9076b', code_json='{"imports": "from mitosheet i…

# %%
# MITO CODE START (DO NOT EDIT)
# SAVED-ANALYSIS-STARTUUID-25511bd5-1b05-498d-8c93-2136d5a9076bSAVED-ANALYSIS-END

from mitosheet import *

# Step 1

temp_df = AAA.drop_duplicates(subset='coid')

df3 = data.merge(temp_df, left_on=['coid'], right_on=['coid'], how='left', suffixes=['_data', '_AAA'])

# Step 2

df3['R'] = 0

# Step 3

df3 = df3.sort_values(by='mdate_data', ascending=False, na_position='first')

df3 = df3.reset_index(drop=True)

# Step 4

df3 = df3.sort_values(by='mdate_data', ascending=True, na_position='first')

df3 = df3.reset_index(drop=True)

# Step 5

df3 = df3.sort_values(by='mdate_data', ascending=True, na_position='first')

df3 = df3.reset_index(drop=True)

# Step 6

data = data[data['acc_code'].str.contains('0010', na=False)]

data = data.reset_index(drop=True)
  
# MITO CODE END (DO NOT EDIT)

# %%
data
# Out:
#         coid                     mdate acc_code  acc_value
# None
# 0     000020 2020-06-01 00:00:00+00:00     0010   636041.0
# 1     000020 2020-06-01 00:00:00+00:00     0020   636041.0
# 2     000020 2020-06-01 00:00:00+00:00     0100   483281.0
# 3     000020 2020-06-01 00:00:00+00:00     0112   391736.0
# 4     000020 2020-06-01 00:00:00+00:00     0115   380000.0
# ...      ...                       ...      ...        ...
# 9995  000104 2020-06-01 00:00:00+00:00     1128        0.0
# 9996  000104 2020-06-01 00:00:00+00:00     1129        NaN
# 9997  000104 2020-06-01 00:00:00+00:00     112A        0.0
# 9998  000104 2020-06-01 00:00:00+00:00     112K        0.0
# 9999  000104 2020-06-01 00:00:00+00:00     112M        0.0
#
# [10000 rows x 4 columns]

# %%
# MITO CODE START (DO NOT EDIT)
# SAVED-ANALYSIS-STARTUUID-0dd04383-b746-4030-8737-90c18805bb4aSAVED-ANALYSIS-END

from mitosheet import *

# Step 1

temp_df = data.drop_duplicates(subset='coid')

df3 = data.merge(temp_df, left_on=['coid'], right_on=['coid'], how='left', suffixes=['_data', '_data_2'])

# Step 2

del df2

# Step 3

temp_df = data.drop_duplicates(subset='coid')

df3 = data.merge(temp_df, left_on=['coid'], right_on=['coid'], how='left', suffixes=['_data', '_data_2'])

# Step 4

del df2

# Step 5

temp_df = data.drop_duplicates(subset='coid')

data_tmp = data.drop(['acc_value', 'acc_code'], axis=1)

data_tmp = temp_df.drop(['acc_value', 'acc_code'], axis=1)

df3 = data_tmp.merge(data_tmp, left_on=['coid'], right_on=['coid'], how='left', suffixes=['_data', '_data_2'])

# Step 6

del df2

# Step 7

df3 = pd.DataFrame(data={})

# Step 8

del df2
  
# MITO CODE END (DO NOT EDIT)

# %%
# Out:
# MitoWidget(analysis_name='UUID-3e8adb99-8796-4222-a8ac-fec78c74ab4b', code_json='{"imports": "from mitosheet i…

# %%
tej
# Out:
#          coid                     mdate    open_d    high_d     low_d  \
# None
# 0        0054 2020-07-31 00:00:00+00:00     25.62     25.65     25.62
# 1        0061 2020-07-31 00:00:00+00:00     20.71     21.06     20.56
# 2      006201 2020-07-31 00:00:00+00:00     15.69     15.83     15.69
# 3       00639 2020-07-31 00:00:00+00:00     14.27     14.57     14.22
# 4      00640L 2020-07-31 00:00:00+00:00     17.28     17.37     16.99
# 5      00641R 2020-07-31 00:00:00+00:00     14.36     14.51     14.35
# 6      00642U 2020-07-31 00:00:00+00:00      8.15      8.20      8.15
# 7       00643 2020-07-31 00:00:00+00:00     17.03     17.43     16.95
# 8      00643K 2020-07-31 00:00:00+00:00      4.02      4.02      4.02
# 9       00645 2020-07-31 00:00:00+00:00     19.73     19.78     19.60
# 10      00657 2020-07-31 00:00:00+00:00     27.30     27.65     27.09
# 11     00657K 2020-07-31 00:00:00+00:00      9.23      9.23      9.23
# ...

# %%
a2330 = []
for df in tmp:
    d = df[df['coid'] == '2330']
    a2330.append(d)
